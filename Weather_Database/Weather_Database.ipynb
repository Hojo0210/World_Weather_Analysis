# %%
# import 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create random lat and longs
lats = np.random.uniform(-90.000 , 90.000 , size = 2000)
longs = np.random.uniform(-180.000 , 180.000 , size = 2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
# add the lat long to a list
coordinates = list(lat_longs)

# %%
# create a list for the cities 
cities = []
# ID nearest city for eact lat/long
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # if its not on the list add it 
    if city not in cities:
        cities.append(city)
# print lengt to confrim count
len(cities)
# Out:
# 732

# %%
# create list for the weather data
city_data = []

# print beginning of logging
print("Beginning Data Retrieval")
print("---------------------------")

# create counters
record_count = 1 
set_count = 1 

# loop through cities
for i, city in enumerate(cities):
    #group by sets of 50 for logging
    if( i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1
    # create endpoint url for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # log URL record and set numbers for city
    print(f"Processing Record {record_count} to Set {set_count} | {city}")
    
    # add to record count
    record_count += 1
    
# run API request for each city
    try:
        # Parse json to retrieve data
        city_weather = requests.get(city_url).json()

        # Parse the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["main"]

        # convert date to ISO format 
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%H:%S')
        # append the city info into city_data 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": weather_description,
                          "Date": city_date

                         })

    # if an error occurs, skip the city 
    except:
        print("City not found. Skipping...")
        pass
# indicate data loading is complete
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 to Set 1 | port alfred
# Processing Record 2 to Set 1 | hobyo
# Processing Record 3 to Set 1 | cabo san lucas
# Processing Record 4 to Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 to Set 1 | provideniya
# Processing Record 6 to Set 1 | vaini
# Processing Record 7 to Set 1 | albany
# Processing Record 8 to Set 1 | pokosnoye
# Processing Record 9 to Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 to Set 1 | jamestown
# Processing Record 11 to Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 to Set 1 | qaanaaq
# Processing Record 13 to Set 1 | sao joao da barra
# Processing Record 14 to Set 1 | hasaki
# Processing Record 15 to Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 to Set 1 | kapaa
# Processing Record 17 to Set 1 | kaitangata
# Processing Record 18 to Set 1 | caiaponia
# Processing Record 19 to Set 1 | rikitea
# Processing Record 20 to Set 1 | riohacha
# Processing Record 21 to Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 to Set 1 | grimari
# City not found. Skipping...
# Processing Record 23 to Set 1 | rio grande
# Processing Record 24 to Set 1 | velikiy ustyug
# Processing Record 25 to Set 1 | broken hill
# Processing Record 26 to Set 1 | bluff
# Processing Record 27 to Set 1 | lebu
# Processing Record 28 to Set 1 | vilyuysk
# Processing Record 29 to Set 1 | hobart
# Processing Record 30 to Set 1 | vostok
# Processing Record 31 to Set 1 | kimbe
# Processing Record 32 to Set 1 | yellowknife
# Processing Record 33 to Set 1 | queimadas
# Processing Record 34 to Set 1 | aklavik
# Processing Record 35 to Set 1 | nador
# Processing Record 36 to Set 1 | birao
# Processing Record 37 to Set 1 | yemtsa
# Processing Record 38 to Set 1 | cape town
# Processing Record 39 to Set 1 | prudnik
# Processing Record 40 to Set 1 | longyearbyen
# Processing Record 41 to Set 1 | fairbanks
# Processing Record 42 to Set 1 | kota kinabalu
# Processing Record 43 to Set 1 | busselton
# Processing Record 44 to Set 1 | dikson
# Processing Record 45 to Set 1 | ancud
# Processing Record 46 to Set 1 | saskylakh
# Processing Record 47 to Set 1 | tuktoyaktuk
# Processing Record 48 to Set 1 | tasiilaq
# Processing Record 49 to Set 1 | balkanabat
# Processing Record 50 to Set 1 | cidreira
# Processing Record 1 to Set 2 | szentkiralyszabadja
# Processing Record 2 to Set 2 | mataura
# Processing Record 3 to Set 2 | mitsamiouli
# Processing Record 4 to Set 2 | ushuaia
# Processing Record 5 to Set 2 | abalak
# Processing Record 6 to Set 2 | luwuk
# Processing Record 7 to Set 2 | bethel
# Processing Record 8 to Set 2 | merauke
# Processing Record 9 to Set 2 | port elizabeth
# Processing Record 10 to Set 2 | klaksvik
# Processing Record 11 to Set 2 | puerto ayora
# Processing Record 12 to Set 2 | barrow
# Processing Record 13 to Set 2 | new norfolk
# Processing Record 14 to Set 2 | meadow lake
# Processing Record 15 to Set 2 | ponta do sol
# Processing Record 16 to Set 2 | hermanus
# Processing Record 17 to Set 2 | mar del plata
# Processing Record 18 to Set 2 | brownsville
# Processing Record 19 to Set 2 | bubaque
# Processing Record 20 to Set 2 | zaysan
# Processing Record 21 to Set 2 | esperance
# Processing Record 22 to Set 2 | tiksi
# Processing Record 23 to Set 2 | kununurra
# Processing Record 24 to Set 2 | husavik
# Processing Record 25 to Set 2 | hithadhoo
# Processing Record 26 to Set 2 | dali
# Processing Record 27 to Set 2 | kuching
# Processing Record 28 to Set 2 | punta arenas
# Processing Record 29 to Set 2 | atuona
# Processing Record 30 to Set 2 | behbahan
# Processing Record 31 to Set 2 | ilulissat
# Processing Record 32 to Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 33 to Set 2 | narsaq
# Processing Record 34 to Set 2 | cherskiy
# Processing Record 35 to Set 2 | lorengau
# Processing Record 36 to Set 2 | saint-philippe
# Processing Record 37 to Set 2 | kirkland lake
# Processing Record 38 to Set 2 | utiroa
# City not found. Skipping...
# Processing Record 39 to Set 2 | khatanga
# Processing Record 40 to Set 2 | geraldton
# Processing Record 41 to Set 2 | clyde river
# Processing Record 42 to Set 2 | yingshang
# City not found. Skipping...
# Processing Record 43 to Set 2 | bambous virieux
# Processing Record 44 to Set 2 | teguldet
# Processing Record 45 to Set 2 | severo-kurilsk
# Processing Record 46 to Set 2 | pangnirtung
# Processing Record 47 to Set 2 | mbuji-mayi
# Processing Record 48 to Set 2 | san patricio
# Processing Record 49 to Set 2 | beaverlodge
# Processing Record 50 to Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 to Set 3 | sangar
# Processing Record 2 to Set 3 | lagunas
# Processing Record 3 to Set 3 | college place
# Processing Record 4 to Set 3 | gornopravdinsk
# Processing Record 5 to Set 3 | portland
# Processing Record 6 to Set 3 | butaritari
# Processing Record 7 to Set 3 | salalah
# Processing Record 8 to Set 3 | yumen
# Processing Record 9 to Set 3 | mirnyy
# Processing Record 10 to Set 3 | simmerath
# Processing Record 11 to Set 3 | tual
# Processing Record 12 to Set 3 | hilo
# Processing Record 13 to Set 3 | mixtequilla
# City not found. Skipping...
# Processing Record 14 to Set 3 | susanville
# Processing Record 15 to Set 3 | carnarvon
# Processing Record 16 to Set 3 | key largo
# Processing Record 17 to Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 to Set 3 | alofi
# Processing Record 19 to Set 3 | khonuu
# City not found. Skipping...
# Processing Record 20 to Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 to Set 3 | raudeberg
# Processing Record 22 to Set 3 | kruisfontein
# Processing Record 23 to Set 3 | kushiro
# Processing Record 24 to Set 3 | nikolskoye
# Processing Record 25 to Set 3 | bathsheba
# Processing Record 26 to Set 3 | placido de castro
# Processing Record 27 to Set 3 | norman wells
# Processing Record 28 to Set 3 | beloha
# Processing Record 29 to Set 3 | port augusta
# Processing Record 30 to Set 3 | quatre cocos
# Processing Record 31 to Set 3 | troitsko-pechorsk
# Processing Record 32 to Set 3 | morehead
# Processing Record 33 to Set 3 | buraydah
# Processing Record 34 to Set 3 | kigali
# Processing Record 35 to Set 3 | kavieng
# Processing Record 36 to Set 3 | antofagasta
# Processing Record 37 to Set 3 | bayir
# Processing Record 38 to Set 3 | bredasdorp
# Processing Record 39 to Set 3 | kieta
# Processing Record 40 to Set 3 | honiara
# Processing Record 41 to Set 3 | kahului
# Processing Record 42 to Set 3 | sabang
# Processing Record 43 to Set 3 | port macquarie
# Processing Record 44 to Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 to Set 3 | mayenne
# Processing Record 46 to Set 3 | deputatskiy
# Processing Record 47 to Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 to Set 3 | chivay
# Processing Record 49 to Set 3 | pitea
# Processing Record 50 to Set 3 | baruun-urt
# Processing Record 1 to Set 4 | constitucion
# Processing Record 2 to Set 4 | cimitarra
# Processing Record 3 to Set 4 | kalmar
# Processing Record 4 to Set 4 | shibarghan
# City not found. Skipping...
# Processing Record 5 to Set 4 | eureka
# Processing Record 6 to Set 4 | bowen
# Processing Record 7 to Set 4 | shaygino
# Processing Record 8 to Set 4 | kodiak
# Processing Record 9 to Set 4 | lasa
# Processing Record 10 to Set 4 | ilhabela
# Processing Record 11 to Set 4 | halifax
# Processing Record 12 to Set 4 | goundam
# Processing Record 13 to Set 4 | astoria
# Processing Record 14 to Set 4 | talnakh
# Processing Record 15 to Set 4 | statesboro
# Processing Record 16 to Set 4 | vao
# Processing Record 17 to Set 4 | pevek
# Processing Record 18 to Set 4 | alma
# Processing Record 19 to Set 4 | georgetown
# Processing Record 20 to Set 4 | pringsewu
# Processing Record 21 to Set 4 | kariba
# Processing Record 22 to Set 4 | broome
# Processing Record 23 to Set 4 | cap-aux-meules
# Processing Record 24 to Set 4 | salinas
# Processing Record 25 to Set 4 | muros
# Processing Record 26 to Set 4 | alice springs
# Processing Record 27 to Set 4 | camacha
# Processing Record 28 to Set 4 | pacocha
# Processing Record 29 to Set 4 | luderitz
# Processing Record 30 to Set 4 | mizdah
# Processing Record 31 to Set 4 | qurayyat
# Processing Record 32 to Set 4 | chuy
# Processing Record 33 to Set 4 | inirida
# Processing Record 34 to Set 4 | coquimbo
# Processing Record 35 to Set 4 | mahebourg
# Processing Record 36 to Set 4 | miramar
# Processing Record 37 to Set 4 | kibala
# Processing Record 38 to Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 39 to Set 4 | byron bay
# Processing Record 40 to Set 4 | fortuna
# Processing Record 41 to Set 4 | bozhou
# Processing Record 42 to Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 to Set 4 | dalbandin
# Processing Record 44 to Set 4 | kintampo
# Processing Record 45 to Set 4 | east london
# Processing Record 46 to Set 4 | padang
# Processing Record 47 to Set 4 | namibe
# Processing Record 48 to Set 4 | tungi
# Processing Record 49 to Set 4 | lima
# Processing Record 50 to Set 4 | rock sound
# Processing Record 1 to Set 5 | havre-saint-pierre
# Processing Record 2 to Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 to Set 5 | lavumisa
# Processing Record 4 to Set 5 | aripuana
# Processing Record 5 to Set 5 | west fargo
# Processing Record 6 to Set 5 | havelock
# Processing Record 7 to Set 5 | andapa
# Processing Record 8 to Set 5 | kavaratti
# Processing Record 9 to Set 5 | karratha
# Processing Record 10 to Set 5 | adrar
# Processing Record 11 to Set 5 | isangel
# Processing Record 12 to Set 5 | kamennogorsk
# Processing Record 13 to Set 5 | presidente medici
# Processing Record 14 to Set 5 | santa maria
# Processing Record 15 to Set 5 | itapetininga
# Processing Record 16 to Set 5 | nhulunbuy
# Processing Record 17 to Set 5 | airai
# Processing Record 18 to Set 5 | avarua
# Processing Record 19 to Set 5 | sitka
# Processing Record 20 to Set 5 | namatanai
# Processing Record 21 to Set 5 | terrace
# Processing Record 22 to Set 5 | guerrero
# Processing Record 23 to Set 5 | san quintin
# Processing Record 24 to Set 5 | port hedland
# Processing Record 25 to Set 5 | shenjiamen
# Processing Record 26 to Set 5 | manggar
# Processing Record 27 to Set 5 | artesia
# Processing Record 28 to Set 5 | gat
# Processing Record 29 to Set 5 | mazamari
# Processing Record 30 to Set 5 | tautira
# Processing Record 31 to Set 5 | tikrit
# Processing Record 32 to Set 5 | roma
# Processing Record 33 to Set 5 | puerto escondido
# Processing Record 34 to Set 5 | fayetteville
# Processing Record 35 to Set 5 | sur
# Processing Record 36 to Set 5 | santa vitoria do palmar
# Processing Record 37 to Set 5 | lufilufi
# Processing Record 38 to Set 5 | zhangzhou
# Processing Record 39 to Set 5 | nome
# Processing Record 40 to Set 5 | hammerfest
# Processing Record 41 to Set 5 | imbituba
# Processing Record 42 to Set 5 | tarudant
# City not found. Skipping...
# Processing Record 43 to Set 5 | mahanje
# Processing Record 44 to Set 5 | karpathos
# Processing Record 45 to Set 5 | jalu
# Processing Record 46 to Set 5 | balakhta
# Processing Record 47 to Set 5 | harper
# Processing Record 48 to Set 5 | codrington
# Processing Record 49 to Set 5 | acaponeta
# Processing Record 50 to Set 5 | yazd
# Processing Record 1 to Set 6 | amapa
# Processing Record 2 to Set 6 | bundaberg
# Processing Record 3 to Set 6 | nishihara
# Processing Record 4 to Set 6 | lompoc
# Processing Record 5 to Set 6 | port hardy
# Processing Record 6 to Set 6 | kutum
# Processing Record 7 to Set 6 | maningrida
# Processing Record 8 to Set 6 | muisne
# Processing Record 9 to Set 6 | dongsheng
# Processing Record 10 to Set 6 | turukhansk
# Processing Record 11 to Set 6 | castro
# Processing Record 12 to Set 6 | lao cai
# Processing Record 13 to Set 6 | nanortalik
# Processing Record 14 to Set 6 | upernavik
# Processing Record 15 to Set 6 | nuuk
# Processing Record 16 to Set 6 | urumqi
# Processing Record 17 to Set 6 | thompson
# Processing Record 18 to Set 6 | lagoa
# Processing Record 19 to Set 6 | luganville
# Processing Record 20 to Set 6 | gniezno
# Processing Record 21 to Set 6 | gorontalo
# Processing Record 22 to Set 6 | katsuura
# Processing Record 23 to Set 6 | yar-sale
# Processing Record 24 to Set 6 | rosarito
# Processing Record 25 to Set 6 | diamantino
# Processing Record 26 to Set 6 | lagos
# Processing Record 27 to Set 6 | bargal
# City not found. Skipping...
# Processing Record 28 to Set 6 | sao filipe
# Processing Record 29 to Set 6 | victor harbor
# Processing Record 30 to Set 6 | ulverstone
# Processing Record 31 to Set 6 | saint peters
# Processing Record 32 to Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 33 to Set 6 | dipkarpaz
# City not found. Skipping...
# Processing Record 34 to Set 6 | iqaluit
# Processing Record 35 to Set 6 | chara
# Processing Record 36 to Set 6 | kouango
# Processing Record 37 to Set 6 | altamira
# Processing Record 38 to Set 6 | la ronge
# Processing Record 39 to Set 6 | faanui
# Processing Record 40 to Set 6 | shawnee
# Processing Record 41 to Set 6 | panaba
# Processing Record 42 to Set 6 | calderitas
# Processing Record 43 to Set 6 | mpanda
# Processing Record 44 to Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 to Set 6 | warqla
# City not found. Skipping...
# Processing Record 46 to Set 6 | marcona
# City not found. Skipping...
# Processing Record 47 to Set 6 | kalmunai
# Processing Record 48 to Set 6 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 49 to Set 6 | cairns
# Processing Record 50 to Set 6 | play cu
# City not found. Skipping...
# Processing Record 1 to Set 7 | souillac
# Processing Record 2 to Set 7 | mount gambier
# Processing Record 3 to Set 7 | ammon
# Processing Record 4 to Set 7 | victoria
# Processing Record 5 to Set 7 | elko
# Processing Record 6 to Set 7 | torbay
# Processing Record 7 to Set 7 | san policarpo
# Processing Record 8 to Set 7 | vila franca do campo
# Processing Record 9 to Set 7 | pisco
# Processing Record 10 to Set 7 | flinders
# Processing Record 11 to Set 7 | homer
# Processing Record 12 to Set 7 | nagato
# Processing Record 13 to Set 7 | haines junction
# Processing Record 14 to Set 7 | samarai
# Processing Record 15 to Set 7 | valparaiso
# Processing Record 16 to Set 7 | los llanos de aridane
# Processing Record 17 to Set 7 | loa janan
# Processing Record 18 to Set 7 | diamantina
# Processing Record 19 to Set 7 | kailua
# Processing Record 20 to Set 7 | higuey
# City not found. Skipping...
# Processing Record 21 to Set 7 | jagdalpur
# Processing Record 22 to Set 7 | inongo
# Processing Record 23 to Set 7 | alto araguaia
# Processing Record 24 to Set 7 | ulladulla
# Processing Record 25 to Set 7 | bukama
# Processing Record 26 to Set 7 | biak
# Processing Record 27 to Set 7 | komsomolskiy
# Processing Record 28 to Set 7 | ternate
# Processing Record 29 to Set 7 | akureyri
# Processing Record 30 to Set 7 | mwinilunga
# Processing Record 31 to Set 7 | concarneau
# Processing Record 32 to Set 7 | bilma
# Processing Record 33 to Set 7 | iralaya
# Processing Record 34 to Set 7 | arraial do cabo
# Processing Record 35 to Set 7 | inhambane
# Processing Record 36 to Set 7 | touros
# Processing Record 37 to Set 7 | goderich
# Processing Record 38 to Set 7 | nguiu
# City not found. Skipping...
# Processing Record 39 to Set 7 | talaya
# Processing Record 40 to Set 7 | vestmannaeyjar
# Processing Record 41 to Set 7 | ribeira grande
# Processing Record 42 to Set 7 | sterling
# Processing Record 43 to Set 7 | abong mbang
# Processing Record 44 to Set 7 | vila velha
# Processing Record 45 to Set 7 | santiago de cao
# Processing Record 46 to Set 7 | christchurch
# Processing Record 47 to Set 7 | ust-uda
# Processing Record 48 to Set 7 | cranbrook
# Processing Record 49 to Set 7 | ikovka
# Processing Record 50 to Set 7 | bara
# Processing Record 1 to Set 8 | ozernovskiy
# Processing Record 2 to Set 8 | sao gabriel da cachoeira
# Processing Record 3 to Set 8 | sorong
# Processing Record 4 to Set 8 | kaiserslautern
# Processing Record 5 to Set 8 | concepcion de buenos aires
# Processing Record 6 to Set 8 | taoudenni
# Processing Record 7 to Set 8 | san cristobal
# Processing Record 8 to Set 8 | tezu
# Processing Record 9 to Set 8 | saint-denis
# Processing Record 10 to Set 8 | oussouye
# Processing Record 11 to Set 8 | yeppoon
# Processing Record 12 to Set 8 | anadyr
# Processing Record 13 to Set 8 | matagami
# Processing Record 14 to Set 8 | bengkulu
# Processing Record 15 to Set 8 | mutis
# Processing Record 16 to Set 8 | phan rang
# City not found. Skipping...
# Processing Record 17 to Set 8 | vila
# Processing Record 18 to Set 8 | muroto
# Processing Record 19 to Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 20 to Set 8 | santa rosa
# Processing Record 21 to Set 8 | mayor pablo lagerenza
# Processing Record 22 to Set 8 | antalaha
# Processing Record 23 to Set 8 | rio gallegos
# Processing Record 24 to Set 8 | millerovo
# Processing Record 25 to Set 8 | sorvag
# City not found. Skipping...
# Processing Record 26 to Set 8 | kitui
# Processing Record 27 to Set 8 | college
# Processing Record 28 to Set 8 | kolo
# Processing Record 29 to Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 30 to Set 8 | batagay-alyta
# Processing Record 31 to Set 8 | arman
# Processing Record 32 to Set 8 | brainerd
# Processing Record 33 to Set 8 | virginia beach
# Processing Record 34 to Set 8 | ostrovnoy
# Processing Record 35 to Set 8 | thomaston
# Processing Record 36 to Set 8 | filingue
# Processing Record 37 to Set 8 | parkersburg
# Processing Record 38 to Set 8 | yamada
# Processing Record 39 to Set 8 | vavoua
# Processing Record 40 to Set 8 | huanren
# Processing Record 41 to Set 8 | vidim
# Processing Record 42 to Set 8 | snezhnogorsk
# Processing Record 43 to Set 8 | chicama
# Processing Record 44 to Set 8 | tevriz
# Processing Record 45 to Set 8 | hambantota
# Processing Record 46 to Set 8 | canmore
# Processing Record 47 to Set 8 | rorvik
# Processing Record 48 to Set 8 | shimanovsk
# Processing Record 49 to Set 8 | mount isa
# Processing Record 50 to Set 8 | jaguey grande
# Processing Record 1 to Set 9 | cayenne
# Processing Record 2 to Set 9 | mocuba
# Processing Record 3 to Set 9 | nizhniy baskunchak
# Processing Record 4 to Set 9 | tura
# Processing Record 5 to Set 9 | pangkalanbuun
# Processing Record 6 to Set 9 | olden
# Processing Record 7 to Set 9 | kerteh
# City not found. Skipping...
# Processing Record 8 to Set 9 | axim
# Processing Record 9 to Set 9 | vangaindrano
# Processing Record 10 to Set 9 | san jose
# Processing Record 11 to Set 9 | dingle
# Processing Record 12 to Set 9 | grajau
# Processing Record 13 to Set 9 | peniche
# Processing Record 14 to Set 9 | lerwick
# Processing Record 15 to Set 9 | petropavlovsk-kamchatskiy
# Processing Record 16 to Set 9 | saint anthony
# Processing Record 17 to Set 9 | oranjestad
# Processing Record 18 to Set 9 | francistown
# Processing Record 19 to Set 9 | fort nelson
# Processing Record 20 to Set 9 | burica
# City not found. Skipping...
# Processing Record 21 to Set 9 | rocha
# Processing Record 22 to Set 9 | sayyan
# Processing Record 23 to Set 9 | phan thiet
# Processing Record 24 to Set 9 | borger
# Processing Record 25 to Set 9 | keti bandar
# Processing Record 26 to Set 9 | san pedro de macoris
# Processing Record 27 to Set 9 | zlitan
# Processing Record 28 to Set 9 | ossora
# Processing Record 29 to Set 9 | marawi
# Processing Record 30 to Set 9 | maragogi
# Processing Record 31 to Set 9 | pitimbu
# Processing Record 32 to Set 9 | buta
# Processing Record 33 to Set 9 | elat
# Processing Record 34 to Set 9 | hervey bay
# Processing Record 35 to Set 9 | cockburn town
# Processing Record 36 to Set 9 | coahuayana
# Processing Record 37 to Set 9 | kudahuvadhoo
# Processing Record 38 to Set 9 | orcopampa
# Processing Record 39 to Set 9 | pacific grove
# Processing Record 40 to Set 9 | saint-augustin
# Processing Record 41 to Set 9 | hay river
# Processing Record 42 to Set 9 | camana
# Processing Record 43 to Set 9 | segou
# Processing Record 44 to Set 9 | dasoguz
# Processing Record 45 to Set 9 | chokurdakh
# Processing Record 46 to Set 9 | warrington
# Processing Record 47 to Set 9 | kloulklubed
# Processing Record 48 to Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 49 to Set 9 | comodoro rivadavia
# Processing Record 50 to Set 9 | hornepayne
# Processing Record 1 to Set 10 | sibu
# Processing Record 2 to Set 10 | zhezkazgan
# Processing Record 3 to Set 10 | khani
# Processing Record 4 to Set 10 | neiafu
# Processing Record 5 to Set 10 | dossor
# Processing Record 6 to Set 10 | zhigansk
# Processing Record 7 to Set 10 | laizhou
# Processing Record 8 to Set 10 | aleysk
# Processing Record 9 to Set 10 | mettur
# Processing Record 10 to Set 10 | bentiu
# Processing Record 11 to Set 10 | emerald
# Processing Record 12 to Set 10 | tabas
# Processing Record 13 to Set 10 | hastings
# Processing Record 14 to Set 10 | dodge city
# Processing Record 15 to Set 10 | naze
# Processing Record 16 to Set 10 | lastoursville
# Processing Record 17 to Set 10 | port moresby
# Processing Record 18 to Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 19 to Set 10 | shieli
# Processing Record 20 to Set 10 | port blair
# Processing Record 21 to Set 10 | mogadishu
# Processing Record 22 to Set 10 | bowmore
# Processing Record 23 to Set 10 | beringovskiy
# Processing Record 24 to Set 10 | monrovia
# Processing Record 25 to Set 10 | margate
# Processing Record 26 to Set 10 | henties bay
# Processing Record 27 to Set 10 | totolapa
# Processing Record 28 to Set 10 | tala
# Processing Record 29 to Set 10 | guilin
# Processing Record 30 to Set 10 | harnosand
# Processing Record 31 to Set 10 | jasper
# Processing Record 32 to Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 to Set 10 | tabou
# Processing Record 34 to Set 10 | sulphur
# Processing Record 35 to Set 10 | aulla
# Processing Record 36 to Set 10 | saint george
# Processing Record 37 to Set 10 | belaya gora
# Processing Record 38 to Set 10 | olafsvik
# Processing Record 39 to Set 10 | pemba
# Processing Record 40 to Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 41 to Set 10 | sechura
# Processing Record 42 to Set 10 | litovko
# Processing Record 43 to Set 10 | mikkeli
# Processing Record 44 to Set 10 | rawson
# Processing Record 45 to Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 46 to Set 10 | bluefield
# Processing Record 47 to Set 10 | chengam
# Processing Record 48 to Set 10 | gustavo diaz ordaz
# Processing Record 49 to Set 10 | makakilo city
# Processing Record 50 to Set 10 | vardo
# Processing Record 1 to Set 11 | goure
# Processing Record 2 to Set 11 | asau
# Processing Record 3 to Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 to Set 11 | camopi
# Processing Record 5 to Set 11 | qaqortoq
# Processing Record 6 to Set 11 | dixon
# Processing Record 7 to Set 11 | kattivakkam
# Processing Record 8 to Set 11 | calvinia
# Processing Record 9 to Set 11 | ust-nera
# Processing Record 10 to Set 11 | tidore
# City not found. Skipping...
# Processing Record 11 to Set 11 | hualmay
# Processing Record 12 to Set 11 | whitehorse
# Processing Record 13 to Set 11 | fare
# Processing Record 14 to Set 11 | kurilsk
# Processing Record 15 to Set 11 | dunedin
# Processing Record 16 to Set 11 | yulara
# Processing Record 17 to Set 11 | delta del tigre
# Processing Record 18 to Set 11 | lata
# Processing Record 19 to Set 11 | sao miguel do araguaia
# Processing Record 20 to Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 21 to Set 11 | tazmalt
# Processing Record 22 to Set 11 | stornoway
# Processing Record 23 to Set 11 | aquiraz
# Processing Record 24 to Set 11 | south venice
# Processing Record 25 to Set 11 | sibolga
# Processing Record 26 to Set 11 | umm kaddadah
# Processing Record 27 to Set 11 | para de minas
# Processing Record 28 to Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 29 to Set 11 | manta
# Processing Record 30 to Set 11 | porto velho
# Processing Record 31 to Set 11 | caravelas
# Processing Record 32 to Set 11 | tutoia
# Processing Record 33 to Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 34 to Set 11 | sampit
# Processing Record 35 to Set 11 | sindou
# Processing Record 36 to Set 11 | mehamn
# Processing Record 37 to Set 11 | southern pines
# Processing Record 38 to Set 11 | sola
# Processing Record 39 to Set 11 | warora
# Processing Record 40 to Set 11 | corinto
# Processing Record 41 to Set 11 | bahia honda
# Processing Record 42 to Set 11 | lensk
# Processing Record 43 to Set 11 | plaine magnien
# Processing Record 44 to Set 11 | ahvaz
# Processing Record 45 to Set 11 | lemesos
# City not found. Skipping...
# Processing Record 46 to Set 11 | deloraine
# Processing Record 47 to Set 11 | kysyl-syr
# Processing Record 48 to Set 11 | agadir
# Processing Record 49 to Set 11 | labuhan
# Processing Record 50 to Set 11 | lolua
# City not found. Skipping...
# Processing Record 1 to Set 12 | salym
# Processing Record 2 to Set 12 | kuandian
# Processing Record 3 to Set 12 | kidal
# Processing Record 4 to Set 12 | oliveira dos brejinhos
# Processing Record 5 to Set 12 | berdigestyakh
# Processing Record 6 to Set 12 | nuevo progreso
# Processing Record 7 to Set 12 | port hawkesbury
# Processing Record 8 to Set 12 | matara
# Processing Record 9 to Set 12 | quarai
# Processing Record 10 to Set 12 | nikolayevsk-na-amure
# Processing Record 11 to Set 12 | nokha
# Processing Record 12 to Set 12 | krasnoselkup
# Processing Record 13 to Set 12 | salinopolis
# Processing Record 14 to Set 12 | colquechaca
# Processing Record 15 to Set 12 | sal rei
# Processing Record 16 to Set 12 | brokopondo
# Processing Record 17 to Set 12 | gramsh
# Processing Record 18 to Set 12 | hofn
# Processing Record 19 to Set 12 | kirovskiy
# Processing Record 20 to Set 12 | moron
# Processing Record 21 to Set 12 | mao
# Processing Record 22 to Set 12 | atessa
# Processing Record 23 to Set 12 | hamilton
# Processing Record 24 to Set 12 | riyadh
# Processing Record 25 to Set 12 | thinadhoo
# Processing Record 26 to Set 12 | baie-comeau
# Processing Record 27 to Set 12 | chukhloma
# Processing Record 28 to Set 12 | tuatapere
# Processing Record 29 to Set 12 | ola
# Processing Record 30 to Set 12 | saldanha
# Processing Record 31 to Set 12 | sioux lookout
# Processing Record 32 to Set 12 | huarmey
# Processing Record 33 to Set 12 | pipri
# Processing Record 34 to Set 12 | borovoy
# Processing Record 35 to Set 12 | napanee
# Processing Record 36 to Set 12 | bhachau
# Processing Record 37 to Set 12 | bawku
# Processing Record 38 to Set 12 | avera
# Processing Record 39 to Set 12 | lavrentiya
# Processing Record 40 to Set 12 | srednekolymsk
# Processing Record 41 to Set 12 | hope
# Processing Record 42 to Set 12 | kamina
# Processing Record 43 to Set 12 | natal
# Processing Record 44 to Set 12 | kainantu
# Processing Record 45 to Set 12 | volsk
# Processing Record 46 to Set 12 | dubai
# Processing Record 47 to Set 12 | abu samrah
# Processing Record 48 to Set 12 | gwadar
# Processing Record 49 to Set 12 | conceicao do araguaia
# Processing Record 50 to Set 12 | wadi maliz
# Processing Record 1 to Set 13 | atar
# Processing Record 2 to Set 13 | tigil
# Processing Record 3 to Set 13 | chunskiy
# Processing Record 4 to Set 13 | orange cove
# Processing Record 5 to Set 13 | moose jaw
# Processing Record 6 to Set 13 | umm lajj
# Processing Record 7 to Set 13 | svetlyy
# Processing Record 8 to Set 13 | muzhi
# Processing Record 9 to Set 13 | chiang khong
# Processing Record 10 to Set 13 | ambon
# Processing Record 11 to Set 13 | kuusamo
# Processing Record 12 to Set 13 | port-gentil
# Processing Record 13 to Set 13 | saint combs
# City not found. Skipping...
# Processing Record 14 to Set 13 | chamonix-mont-blanc
# Processing Record 15 to Set 13 | jinchang
# Processing Record 16 to Set 13 | marienburg
# Processing Record 17 to Set 13 | pak phanang
# Processing Record 18 to Set 13 | la asuncion
# Processing Record 19 to Set 13 | leningradskiy
# Processing Record 20 to Set 13 | ozgon
# City not found. Skipping...
# Processing Record 21 to Set 13 | sao jose da coroa grande
# Processing Record 22 to Set 13 | de aar
# Processing Record 23 to Set 13 | nenjiang
# Processing Record 24 to Set 13 | bagdarin
# Processing Record 25 to Set 13 | santa cruz del norte
# Processing Record 26 to Set 13 | redmond
# Processing Record 27 to Set 13 | belfast
# Processing Record 28 to Set 13 | beyneu
# Processing Record 29 to Set 13 | la rioja
# Processing Record 30 to Set 13 | chik
# Processing Record 31 to Set 13 | launceston
# Processing Record 32 to Set 13 | meulaboh
# Processing Record 33 to Set 13 | nueve de julio
# Processing Record 34 to Set 13 | konstantinovsk
# Processing Record 35 to Set 13 | skiros
# City not found. Skipping...
# Processing Record 36 to Set 13 | boa vista
# Processing Record 37 to Set 13 | houma
# Processing Record 38 to Set 13 | mandalgovi
# Processing Record 39 to Set 13 | puerto el triunfo
# Processing Record 40 to Set 13 | le port
# Processing Record 41 to Set 13 | naron
# Processing Record 42 to Set 13 | normandin
# Processing Record 43 to Set 13 | gravdal
# Processing Record 44 to Set 13 | tottori
# Processing Record 45 to Set 13 | saint paul
# Processing Record 46 to Set 13 | half moon bay
# Processing Record 47 to Set 13 | namikupa
# Processing Record 48 to Set 13 | te anau
# Processing Record 49 to Set 13 | saint-georges
# Processing Record 50 to Set 13 | awbari
# Processing Record 1 to Set 14 | takaungu
# Processing Record 2 to Set 14 | paamiut
# Processing Record 3 to Set 14 | san andres
# Processing Record 4 to Set 14 | lotofaga
# Processing Record 5 to Set 14 | cedar city
# Processing Record 6 to Set 14 | bilibino
# Processing Record 7 to Set 14 | tunxi
# City not found. Skipping...
# Processing Record 8 to Set 14 | perelyub
# Processing Record 9 to Set 14 | loikaw
# Processing Record 10 to Set 14 | kashi
# Processing Record 11 to Set 14 | nedjo
# Processing Record 12 to Set 14 | sychevka
# Processing Record 13 to Set 14 | boulder
# Processing Record 14 to Set 14 | bagotville
# Processing Record 15 to Set 14 | cortes
# Processing Record 16 to Set 14 | ivanteyevka
# Processing Record 17 to Set 14 | carutapera
# Processing Record 18 to Set 14 | sambava
# Processing Record 19 to Set 14 | santa isabel do rio negro
# Processing Record 20 to Set 14 | mahon
# Processing Record 21 to Set 14 | satitoa
# City not found. Skipping...
# Processing Record 22 to Set 14 | baracoa
# Processing Record 23 to Set 14 | ihosy
# Processing Record 24 to Set 14 | mugur-aksy
# Processing Record 25 to Set 14 | guerrero negro
# Processing Record 26 to Set 14 | guayabetal
# Processing Record 27 to Set 14 | tallahassee
# Processing Record 28 to Set 14 | alta floresta
# Processing Record 29 to Set 14 | tianpeng
# Processing Record 30 to Set 14 | lazaro cardenas
# Processing Record 31 to Set 14 | koforidua
# Processing Record 32 to Set 14 | royal tunbridge wells
# Processing Record 33 to Set 14 | iskateley
# Processing Record 34 to Set 14 | aras
# Processing Record 35 to Set 14 | milkovo
# Processing Record 36 to Set 14 | vanimo
# Processing Record 37 to Set 14 | baghdad
# Processing Record 38 to Set 14 | tabuk
# Processing Record 39 to Set 14 | nakskov
# Processing Record 40 to Set 14 | gien
# Processing Record 41 to Set 14 | miraflores
# Processing Record 42 to Set 14 | kyren
# Processing Record 43 to Set 14 | villa carlos paz
# Processing Record 44 to Set 14 | rimbey
# Processing Record 45 to Set 14 | misratah
# Processing Record 46 to Set 14 | tessalit
# Processing Record 47 to Set 14 | karlskoga
# Processing Record 48 to Set 14 | barao de melgaco
# Processing Record 49 to Set 14 | belmonte
# Processing Record 50 to Set 14 | tazovskiy
# Processing Record 1 to Set 15 | januaria
# Processing Record 2 to Set 15 | pulandian
# Processing Record 3 to Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 4 to Set 15 | newport
# Processing Record 5 to Set 15 | hasanabad
# Processing Record 6 to Set 15 | eldorado
# Processing Record 7 to Set 15 | acari
# Processing Record 8 to Set 15 | labutta
# City not found. Skipping...
# Processing Record 9 to Set 15 | riwaka
# Processing Record 10 to Set 15 | pershotravneve
# Processing Record 11 to Set 15 | bonito
# Processing Record 12 to Set 15 | virden
# Processing Record 13 to Set 15 | sorland
# Processing Record 14 to Set 15 | catamarca
# Processing Record 15 to Set 15 | kangaatsiaq
# Processing Record 16 to Set 15 | aksu
# Processing Record 17 to Set 15 | seddon
# Processing Record 18 to Set 15 | gorom-gorom
# Processing Record 19 to Set 15 | boke
# Processing Record 20 to Set 15 | pangody
# Processing Record 21 to Set 15 | iwaki
# Processing Record 22 to Set 15 | juifang
# City not found. Skipping...
# Processing Record 23 to Set 15 | shaowu
# Processing Record 24 to Set 15 | ylivieska
# Processing Record 25 to Set 15 | novoulyanovsk
# Processing Record 26 to Set 15 | sembakung
# Processing Record 27 to Set 15 | chernyshevskiy
# Processing Record 28 to Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 29 to Set 15 | idlib
# Processing Record 30 to Set 15 | pijijiapan
# Processing Record 31 to Set 15 | itoman
# Processing Record 32 to Set 15 | northam
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
len(city_data)
# Out:
# 674

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Port Alfred      ZA -33.5906   26.8910     59.85        81
# 1              Hobyo      SO   5.3505   48.5268     78.40        82
# 2     Cabo San Lucas      MX  22.8909 -109.9124     96.51        53
# 3        Provideniya      RU  64.3833 -173.3000     46.51        57
# 4              Vaini      TO -21.2000 -175.2000     77.16        69
# 5             Albany      US  42.6001  -73.9662     64.58        48
# 6          Pokosnoye      RU  55.5258  101.0536     45.03        49
# 7          Jamestown      US  42.0970  -79.2353     59.29        53
# 8            Qaanaaq      GL  77.4840  -69.3632     38.19        72
# 9  Sao Joao Da Barra      BR -21.6403  -41.0511     72.05        89
#
#    Cloudiness  Wind Speed Description                 Date
# 0          92       10.71      Clouds  2021-05-27 23:23:42
# 1          57       18.84      Clouds  2021-05-27 23:23:43
# 2          61       10.83      Clouds  2021-05-27 23:23:27
# 3           0       15.66       Clear  2021-05-27 23:23:05
# 4          20       11.50      Clouds  2021-05-27 23:23:05
# 5          42        7.00      Clouds  2021-05-27 23:23:07
# 6          78        7.38      Clouds  2021-05-27 23:23:06
# 7          86        1.99      Clouds  2021-05-27 23:23:22
# 8         100        7.63      Clouds  2021-05-27 23:23:06
# 9          15        4.92      Clouds  2021-05-27 23:23:07

# %%
# create output file
output_data_file = "WeatherPy_Database.csv"

# export to csv
city_data_df.to_csv(output_data_file, index_label = "City ID")
